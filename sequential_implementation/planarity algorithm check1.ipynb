# %%
import sys
sys.path.append('./paralel_planarity_criterion')

# %%
def print_cycle_edge_table(boolean_list, edge_map, cycle_map):
    # Get the number of edges (columns) and cycles (rows)
    num_edges = len(set(edge_map.values()))
    num_cycles = len(cycle_map)

    # Invert cycle_map to get row index to cycle mapping
    cycle_indices = {v: k for k, v in cycle_map.items()}
    edge_indices = {v: k for k, v in edge_map.items() if v in set(edge_map.values())}

    # Prepare column widths based on edge tuple lengths
    col_widths = []
    for col in range(num_edges):
        edge_label = str(edge_indices[col])
        col_widths.append(len(edge_label) + 2)  # +2 for padding

    # Determine max width for the first column based on the longest cycle label
    max_cycle_len = max(len(str(cycle_indices[row])) for row in range(num_cycles))
    first_col_width = max(max_cycle_len, len("Cycle/Edge")) + 2  # Add padding

    # Print header
    header = "Cycle/Edge".ljust(first_col_width)
    for col in range(num_edges):
        edge_label = str(edge_indices[col])
        header += edge_label.ljust(col_widths[col])
    print(header)
    print('-' * len(header))

    # Print each row
    for row in range(num_cycles):
        cycle = str(cycle_indices[row])
        row_values = boolean_list[row * num_edges: (row + 1) * num_edges]
        row_str = cycle.ljust(first_col_width)
        for col, val in enumerate(row_values):
            row_str += ('True' if val else 'False').ljust(col_widths[col])
        print(row_str)

# %%
import networkx as nx
import random


import triconnected_components as tcc ### TODO CAMBIAR AL CAMBIAR NOMBRE 
import printers 
finder = tcc.TriconnectedFinder()
printer = printers.ConnectedComponentsDrawer()

# Import your solver class
from planarity_criterion import PlanarityCriterion  # Replace with your actual module name if different

# Initialize solver
solver = PlanarityCriterion()

def generate_graphs(num_planar, num_nonplanar, seed=42): ### CON SEED 42 VA BIEN PERO SE PILLA CON LOS QUE NO SON PLANARES.
    """
    Generate a list of planar and non-planar graphs using NetworkX's check_planarity.
    """
    random.seed(seed)
    planar_graphs = []
    nonplanar_graphs = []
    trials = 0

    while len(planar_graphs) < num_planar or len(nonplanar_graphs) < num_nonplanar:
        n = random.randint(5, 10)   # number of nodes
        m = random.randint(n, n * (n - 1) // 2)  # number of edges
        G = nx.gnm_random_graph(n, m, seed=seed + trials)
        
        is_planar, _ = nx.check_planarity(G)
        
        if is_planar and len(planar_graphs) < num_planar:
            planar_graphs.append(G)
        elif not is_planar and len(nonplanar_graphs) < num_nonplanar:
            nonplanar_graphs.append(G)
        
        trials += 1  # change seed for the next trial

    return planar_graphs, nonplanar_graphs

import random
# Generate 5 planar and 5 non-planar graphs
seed = random.randint(1, 100)
planar_graphs, nonplanar_graphs = generate_graphs(50, 50, seed)


# Test on non-planar graphs
print("\nTesting Non-Planar Graphs:")
for i, G in enumerate(nonplanar_graphs):
    # print("nodos grafo:", G.nodes())
    # print("edges grafo:", G.edges())
    my_result, info = solver.is_planar(G)
    nx_result, _ = nx.check_planarity(G)
    print(f"Graph {i+1}: NetworkX: {nx_result}, Your method: {my_result}, Match: {my_result == nx_result}")
    if (my_result != nx_result):
        print()
        print()
        print("FAILED RESULT !!!!!!")
        print("seed: ", seed)
        print()
        print()
    print()
    print()

# Test on planar graphs
print("Testing Planar Graphs:")
for i, G in enumerate(planar_graphs):
    # print("nodos grafo:", G.nodes())
    # print("edges grafo:", G.edges())
    
    tcc, _ = finder.triconnected_comps(G)
    # print("Graph Triconnected Components:")
    # printer.print_n_connected_components(G, tcc, N=3)
    
    my_result, info = solver.is_planar(G)
    # print_cycle_edge_table(info["truth_assign"], info["edge_index_map"], info["cycle_index_map"])
    if not my_result: print("\n\nfailing tcc:", info["failing tcc"].nodes(), info["failing tcc"].edges(), "\n\n")
    #print("info:", info)
    
    nx_result, _ = nx.check_planarity(G)
    print(f"Graph {i+1}: NetworkX: {nx_result}, Your method: {my_result}, Match: {my_result == nx_result}")
    if (my_result != nx_result):
        print()
        print()
        print("FAILED RESULT !!!!!!")
        print("seed: ", seed)
        print()
        print()
    print()
    print()
# Out:
# Testing Non-Planar Graphs:
# Graph 1: NetworkX: False, Your method: False, Match: True
#
#
# Graph 2: NetworkX: False, Your method: False, Match: True
#
#
# Graph 3: NetworkX: False, Your method: False, Match: True
#
#
# Graph 4: NetworkX: False, Your method: False, Match: True
#
#
# Graph 5: NetworkX: False, Your method: False, Match: True
#
#
# Graph 6: NetworkX: False, Your method: False, Match: True
#
#
# Graph 7: NetworkX: False, Your method: False, Match: True
#
#
# Graph 8: NetworkX: False, Your method: False, Match: True
#
#
# Graph 9: NetworkX: False, Your method: False, Match: True
#
#
# Graph 10: NetworkX: False, Your method: False, Match: True
#
#
# Graph 11: NetworkX: False, Your method: False, Match: True
#
#
# Graph 12: NetworkX: False, Your method: False, Match: True
#
#
# Graph 13: NetworkX: False, Your method: False, Match: True
#
#
# Graph 14: NetworkX: False, Your method: False, Match: True
#
#
# Graph 15: NetworkX: False, Your method: False, Match: True
#
#
# Graph 16: NetworkX: False, Your method: False, Match: True
#
#
# Graph 17: NetworkX: False, Your method: False, Match: True
#
#
# Graph 18: NetworkX: False, Your method: False, Match: True
#
#
# Graph 19: NetworkX: False, Your method: False, Match: True
#
#
# Graph 20: NetworkX: False, Your method: False, Match: True
#
#
# Graph 21: NetworkX: False, Your method: False, Match: True
#
#
# Graph 22: NetworkX: False, Your method: False, Match: True
#
#
# Graph 23: NetworkX: False, Your method: False, Match: True
#
#
# Graph 24: NetworkX: False, Your method: False, Match: True
#
#
# Graph 25: NetworkX: False, Your method: False, Match: True
#
#
# Graph 26: NetworkX: False, Your method: False, Match: True
#
#
# Graph 27: NetworkX: False, Your method: False, Match: True
#
#
# Graph 28: NetworkX: False, Your method: False, Match: True
#
#
# Graph 29: NetworkX: False, Your method: False, Match: True
#
#
# Graph 30: NetworkX: False, Your method: False, Match: True
#
#
# Graph 31: NetworkX: False, Your method: False, Match: True
#
#
# Graph 32: NetworkX: False, Your method: False, Match: True
#
#
# Graph 33: NetworkX: False, Your method: False, Match: True
#
#
# Graph 34: NetworkX: False, Your method: False, Match: True
#
#
# Graph 35: NetworkX: False, Your method: False, Match: True
#
#
# Graph 36: NetworkX: False, Your method: False, Match: True
#
#
# Graph 37: NetworkX: False, Your method: False, Match: True
#
#
# Graph 38: NetworkX: False, Your method: False, Match: True
#
#
# Graph 39: NetworkX: False, Your method: False, Match: True
#
#
# Graph 40: NetworkX: False, Your method: False, Match: True
#
#
# Graph 41: NetworkX: False, Your method: False, Match: True
#
#
# Graph 42: NetworkX: False, Your method: False, Match: True
#
#
# Graph 43: NetworkX: False, Your method: False, Match: True
#
#
# Graph 44: NetworkX: False, Your method: False, Match: True
#
#
# Graph 45: NetworkX: False, Your method: False, Match: True
#
#
# Graph 46: NetworkX: False, Your method: False, Match: True
#
#
# Graph 47: NetworkX: False, Your method: False, Match: True
#
#
# Graph 48: NetworkX: False, Your method: False, Match: True
#
#
# Graph 49: NetworkX: False, Your method: False, Match: True
#
#
# Graph 50: NetworkX: False, Your method: False, Match: True
#
#
# Testing Planar Graphs:
# Graph 1: NetworkX: True, Your method: True, Match: True
#
#
# Graph 2: NetworkX: True, Your method: True, Match: True
#
#
# Graph 3: NetworkX: True, Your method: True, Match: True
#
#
# Graph 4: NetworkX: True, Your method: True, Match: True
#
#
# Graph 5: NetworkX: True, Your method: True, Match: True
#
#
# Graph 6: NetworkX: True, Your method: True, Match: True
#
#
# Graph 7: NetworkX: True, Your method: True, Match: True
#
#
# Graph 8: NetworkX: True, Your method: True, Match: True
#
#
# Graph 9: NetworkX: True, Your method: True, Match: True
#
#
# Graph 10: NetworkX: True, Your method: True, Match: True
#
#
# Graph 11: NetworkX: True, Your method: True, Match: True
#
#
# Graph 12: NetworkX: True, Your method: True, Match: True
#
#
# Graph 13: NetworkX: True, Your method: True, Match: True
#
#
# Graph 14: NetworkX: True, Your method: True, Match: True
#
#
# Graph 15: NetworkX: True, Your method: True, Match: True
#
#
# Graph 16: NetworkX: True, Your method: True, Match: True
#
#
# Graph 17: NetworkX: True, Your method: True, Match: True
#
#
# Graph 18: NetworkX: True, Your method: True, Match: True
#
#
# Graph 19: NetworkX: True, Your method: True, Match: True
#
#
# Graph 20: NetworkX: True, Your method: True, Match: True
#
#
# Graph 21: NetworkX: True, Your method: True, Match: True
#
#
# Graph 22: NetworkX: True, Your method: True, Match: True
#
#
# Graph 23: NetworkX: True, Your method: True, Match: True
#
#
# Graph 24: NetworkX: True, Your method: True, Match: True
#
#
# Graph 25: NetworkX: True, Your method: True, Match: True
#
#
# Graph 26: NetworkX: True, Your method: True, Match: True
#
#
# Graph 27: NetworkX: True, Your method: True, Match: True
#
#
# Graph 28: NetworkX: True, Your method: True, Match: True
#
#
# Graph 29: NetworkX: True, Your method: True, Match: True
#
#
# Graph 30: NetworkX: True, Your method: True, Match: True
#
#
# Graph 31: NetworkX: True, Your method: True, Match: True
#
#
# Graph 32: NetworkX: True, Your method: True, Match: True
#
#
# Graph 33: NetworkX: True, Your method: True, Match: True
#
#
# Graph 34: NetworkX: True, Your method: True, Match: True
#
#
# Graph 35: NetworkX: True, Your method: True, Match: True
#
#
# Graph 36: NetworkX: True, Your method: True, Match: True
#
#
# Graph 37: NetworkX: True, Your method: True, Match: True
#
#
# Graph 38: NetworkX: True, Your method: True, Match: True
#
#
# Graph 39: NetworkX: True, Your method: True, Match: True
#
#
# Graph 40: NetworkX: True, Your method: True, Match: True
#
#
# Graph 41: NetworkX: True, Your method: True, Match: True
#
#
# Graph 42: NetworkX: True, Your method: True, Match: True
#
#
# Graph 43: NetworkX: True, Your method: True, Match: True
#
#
# Graph 44: NetworkX: True, Your method: True, Match: True
#
#
# Graph 45: NetworkX: True, Your method: True, Match: True
#
#
# Graph 46: NetworkX: True, Your method: True, Match: True
#
#
# Graph 47: NetworkX: True, Your method: True, Match: True
#
#
# Graph 48: NetworkX: True, Your method: True, Match: True
#
#
# Graph 49: NetworkX: True, Your method: True, Match: True
#
#
# Graph 50: NetworkX: True, Your method: True, Match: True
