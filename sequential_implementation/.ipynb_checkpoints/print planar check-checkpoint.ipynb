# %%
import sys
sys.path.append('./paralel_planarity_criterion')

# %%
import networkx as nx
import random
import planar_printer


# Set a fixed seed for reproducibility
seed = 41

# === Planar graph ===
# We'll generate a random graph and filter until we get one planar graph
random.seed(seed)
planar_graph = None
trials = 0
while planar_graph is None:
    n = random.randint(5, 10)
    m = random.randint(n, n * (n - 1) // 2)
    G = nx.gnm_random_graph(n, m, seed=seed + trials)
    is_planar, _ = nx.check_planarity(G)
    if is_planar:
        planar_graph = G
    trials += 1

# === Non-planar graph ===
# Similarly generate a non-planar graph
random.seed(seed + 1000)
nonplanar_graph = None
trials = 0
while nonplanar_graph is None:
    n = random.randint(5, 10)
    m = random.randint(n, n * (n - 1) // 2)
    G = nx.gnm_random_graph(n, m, seed=seed + 1000 + trials)
    is_planar, _ = nx.check_planarity(G)
    if not is_planar:
        nonplanar_graph = G
    trials += 1

# === Test Planar Graph ===
print("Testing Planar Graph:")
print("Nodes:", planar_graph.nodes())
print("Edges:", planar_graph.edges())
planar_list, coordinates = planar_printer.get_embbeding(planar_graph)
#print(info["failing tcc"].nodes(), info["failing tcc"].edges())

# === Test Non-Planar Graph ===
print("\nTesting Non-Planar Graph:")
print("Nodes:", nonplanar_graph.nodes())
print("Edges:", nonplanar_graph.edges())
planar_list, coordinates = planar_printer.get_embbeding(nonplanar_graph)
# Out:
# Testing Planar Graph:
# Nodes: [0, 1, 2, 3, 4, 5]
# Edges: [(0, 5), (0, 4), (0, 1), (1, 2), (1, 4), (1, 3), (3, 4), (4, 5)]
# final graph:
# {0: (np.float64(-1.8369701987210297e-16), np.float64(-1.0)), 4: (np.float64(6.123233995736766e-17), np.float64(1.0)), 5: (np.float64(-1.0), np.float64(1.2246467991473532e-16)), 1: (np.float64(6.123233995736766e-17), np.float64(1.0)), 3: (np.float64(-0.9999999999999998), np.float64(2.0))}
# {0: (np.float64(-1.8369701987210297e-16), np.float64(-1.0)), 4: (np.float64(6.123233995736766e-17), np.float64(1.0)), 5: (np.float64(-1.0), np.float64(1.2246467991473532e-16)), 1: (np.float64(6.123233995736766e-17), np.float64(1.0)), 3: (np.float64(-0.9999999999999998), np.float64(2.0)), 2: (np.float64(0.5000000000000001), np.float64(1.5))}
# Testing Non-Planar Graph:
# Nodes: [0, 1, 2, 3, 4, 5, 6, 7]
# Edges: [(0, 3), (0, 4), (1, 3), (1, 6), (1, 7), (2, 7), (2, 3), (2, 6), (3, 7), (3, 5), (4, 6), (4, 7), (6, 7)]

# %%
def generate_graphs(num_planar, num_nonplanar, seed=42): ### CON SEED 42 VA BIEN PERO SE PILLA CON LOS QUE NO SON PLANARES.
    """
    Generate a list of planar and non-planar graphs using NetworkX's check_planarity.
    """
    random.seed(seed)
    planar_graphs = []
    nonplanar_graphs = []
    trials = 0

    while len(planar_graphs) < num_planar or len(nonplanar_graphs) < num_nonplanar:
        n = random.randint(5, 10)   # number of nodes
        m = random.randint(n, n * (n - 1) // 2)  # number of edges
        G = nx.gnm_random_graph(n, m, seed=seed + trials)
        
        is_planar, _ = nx.check_planarity(G)
        
        if is_planar and len(planar_graphs) < num_planar:
            planar_graphs.append(G)
        elif not is_planar and len(nonplanar_graphs) < num_nonplanar:
            nonplanar_graphs.append(G)
        
        trials += 1  # change seed for the next trial

    return planar_graphs, nonplanar_graphs

import random
# Generate 5 planar and 5 non-planar graphs
seed = random.randint(1, 100)
planar_graphs, nonplanar_graphs = generate_graphs(5, 5, 42)


# Test on planar graphs
print("Testing Planar Graphs:")
for i, G in enumerate(planar_graphs):
    print("nodos grafo:", G.nodes())
    print("edges grafo:", G.edges())
    
    # tcc, _ = finder.triconnected_comps(G)
    # print("Graph Triconnected Components:")
    # printer.print_n_connected_components(G, tcc, N=3)
    
    planar_list, coordinates = planar_printer.get_embbeding_not_TCC(G)

"""
# Test on non-planar graphs
print("\nTesting Non-Planar Graphs:")
for i, G in enumerate(nonplanar_graphs):
    # print("nodos grafo:", G.nodes())
    # print("edges grafo:", G.edges())
    planar_list, coordinates = planar_printer.get_embbeding(G)
"""
# Out:
# Testing Planar Graphs:
# nodos grafo: [0, 1, 2, 3, 4, 5, 6]
# edges grafo: [(0, 4), (0, 2), (0, 6), (1, 6), (1, 5), (2, 4), (2, 3), (3, 5), (3, 6), (4, 6)]
# nodos grafo: [0, 1, 2, 3, 4]
# edges grafo: [(0, 4), (0, 2), (0, 1), (1, 4), (2, 4)]
# ---------------------------------------------------------------------------
# NodeNotFound                              Traceback (most recent call last)
# Cell In[3], line 42
#      36     print("edges grafo:", G.edges())
#      38     # tcc, _ = finder.triconnected_comps(G)
#      39     # print("Graph Triconnected Components:")
#      40     # printer.print_n_connected_components(G, tcc, N=3)
# ---> 42     planar_list, coordinates = planar_printer.get_embbeding_not_TCC(G)
#      44 """
#      45 # Test on non-planar graphs
#      46 print("\nTesting Non-Planar Graphs:")
#    (...)
#      50     planar_list, coordinates = planar_printer.get_embbeding(G)
#      51 """
#
# File ~\Documents\uni\TFG\Planar_graphs\TFG_code\sequential_implementation\./paralel_planarity_criterion\planar_printer.py:280, in get_embbeding_not_TCC(G)
#     276 criterion = planarity_criterion.PlanarityCriterion()
#     278 spanning_tree = criterion.spanning_tree(G)
# --> 280 fundamental_cycles = criterion.fundamental_cycles(G, spanning_tree)
#     282 bridges = criterion.get_bridges(G, fundamental_cycles)
#     284 truth_assign, info = criterion.get_truth_assigment(
#     285     G, fundamental_cycles, bridges
#     286     )
#
# File ~\Documents\uni\TFG\Planar_graphs\TFG_code\sequential_implementation\./paralel_planarity_criterion\planarity_criterion.py:52, in PlanarityCriterion.fundamental_cycles(self, G, spanning_tree_undirected)
#      49 fundamental_cycles = []
#      50 for u, v in generating_edges:
#      51     # Find the path in the spanning tree between u and v
# ---> 52     path = nx.shortest_path(
#      53         spanning_tree_undirected, source=u, target=v)
#      54     cycle = path + [u]  # Complete the cycle
#      55     fundamental_cycles.append(cycle)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 52:3, in argmap_shortest_path_49(G, source, target, weight, method, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~\.conda\envs\MacLane1\Lib\site-packages\networkx\utils\backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~\.conda\envs\MacLane1\Lib\site-packages\networkx\algorithms\shortest_paths\generic.py:183, in shortest_path(G, source, target, weight, method)
#     180 else:
#     181     # Find shortest source-target path.
#     182     if method == "unweighted":
# --> 183         paths = nx.bidirectional_shortest_path(G, source, target)
#     184     elif method == "dijkstra":
#     185         _, paths = nx.bidirectional_dijkstra(G, source, target, weight)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 56:3, in argmap_bidirectional_shortest_path_53(G, source, target, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~\.conda\envs\MacLane1\Lib\site-packages\networkx\utils\backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~\.conda\envs\MacLane1\Lib\site-packages\networkx\algorithms\shortest_paths\unweighted.py:244, in bidirectional_shortest_path(G, source, target)
#     205 """Returns a list of nodes in a shortest path between source and target.
#     206
#     207 Parameters
#    (...)
#     240 This algorithm is used by shortest_path(G, source, target).
#     241 """
#     243 if source not in G:
# --> 244     raise nx.NodeNotFound(f"Source {source} is not in G")
#     246 if target not in G:
#     247     raise nx.NodeNotFound(f"Target {target} is not in G")
#
# NodeNotFound: Source 0 is not in G
